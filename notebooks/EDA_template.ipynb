# %% [markdown]
# # EDA Template
#
# Use this notebook to explore `listings.csv` and `calendar.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
city = 'nyc'  # change me
listings = pd.read_csv(Path('data')/city/'listings.csv', low_memory=False)
calendar = pd.read_csv(Path('data')/city/'calendar.csv', low_memory=False)
listings.head()
